# %% [markdown]
# # Aula 03
# Aprendizado supervisionado: classificação

# %%
import pandas as pd

# %%
link = 'https://raw.githubusercontent.com/FLS-6497/datasets/main/aula3/PKAP_raw_data.csv'
dados = pd.read_csv(link, encoding = "latin")

# %% [markdown]
# ## a) Exploração de features
# Faça gráficos de barras com a frequência da variável race por cada uma das variáveis officer_ na base de dados. O resultado deve indicar quantas vítimas de mortes por violência letal policial de diferentes raças (whites e blacks) ocorreram em diferentes categorias (e.g., office_offduty). Dica: algumas variáveis precisam ser recategorizadas porque possuem muitas categorias com poucas ocorrências.

# %%
dados.head()
# Out:
#                 name  id  age  gender   race    month  day  year  \
# 0   Lewis Lembke\r\n   4   47    Male  White  January    2  2015
# 1  Michael Kocher Jr   5   19    Male  White  January    3  2015
# 2     Patrick Wetter  11   25    Male  White  January    6  2015
# 3      Autumn Steele  13   34  Female  White  January    6  2015
# 4      Brock Nichols  14   35    Male  White  January    6  2015
#
#       classification    armed  ... mental suicide_by_cop intox  \
# 0            Gunshot  Firearm  ...     No            NaN   Yes
# 1  Struck by vehicle       No  ...     No            NaN    No
# 2            Gunshot    Knife  ...     No            NaN   Yes
# 3            Gunshot       No  ...     No            NaN    No
# 4            Gunshot  Firearm  ...     No            NaN   Yes
#
#                     deced_personal  \
# 0             Had children,Married
# 1                None of the above
# 2                None of the above
# 3            Married, Had children
# 4  Had children,Divorced/Separated
#
#                                        deced_descrip  \
# 0                                  None of the above
# 1                                  None of the above
# 2                                  None of the above
# 3  Recently released from jail or prison (Less th...
# 4                                  None of the above
#
#                                         deced_occupy criminal_rec violent_rec  \
# 0              No employment or education info given           No         NaN
# 1  Employed. Specify occupation and/or business, ...           No         NaN
# 2              No employment or education info given           No         NaN
# 3              No employment or education info given          Yes         Yes
# 4  Employed. Specify occupation and/or business,E...           No         NaN
#
#   video video_public
# 0    No          NaN
# 1    No          NaN
# 2    No          NaN
# 3   Yes          Yes
# 4    No          NaN
#
# [5 rows x 57 columns]
